# %%
print("Jai ganesh")
# Out:
# Jai ganesh

# %%
str1="""Here is a suggested plan:
Morning - visit Shanivar wada,
Afternoon - visit a Dagadusheth temple,
Evening - have dinner."""

# %%
list1=[
{"time":"Morning","activity":"shanivar wada"},
{"time":"Afternoon","activity":"Dagadusheth temple"},
{"time":"Evening","activity":"Dinner at hotel"}
]

# %%
list->{} -> "time" "activty"

# %%
list1[2]["time"]
# Out:
# 'Evening'

# %%
list1[2]["activity"]
# Out:
# 'Dinner at hotel'
